# %%
import numpy as np
import pandas as pd
import os

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import pywt
from PIL import Image  
import PIL  
from skimage.io import imsave, imread

# %%
from dask import bag, diagnostics 
#import hvplot.pandas
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import shutil

import cv2
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay, zero_one_loss, classification_report
import seaborn as sns
from tensorflow import keras
import matplotlib.cm as cm
from IPython.display import Image, display

from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from keras.layers import Input
from keras.layers import Convolution2D , concatenate ,Conv2D,Dense
from keras.layers import Activation,Dropout, GlobalAveragePooling2D,MaxPooling2D
from keras.models import Model
from keras.optimizers import Adam ,SGD,RMSprop

# %%
import math
from keras.layers import MaxPool2D, concatenate, AveragePooling2D
import tensorflow as tf
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint
import h5py
from keras.layers import Concatenate
import keras.backend as K
import keras
from keras.utils import np_utils
from keras.callbacks import LearningRateScheduler

# %%
data_path = '/content/drive/MyDrive/Sem 2/CV/5G_Data_rev/'

# %%
classes = list(os.listdir('/content/drive/MyDrive/Sem 2/CV/5G_Data_rev/'))
print(classes)
# Out:
# ['64QAM', '4QAM', '16QAM']

# %%
directories = {
    '4QAM': '/content/drive/MyDrive/Sem 2/CV/5G_Data_rev/4QAM/',
#    '8QAM': '/content/drive/MyDrive/Sem 2/CV/5G_Data/8QAM/',
    '16QAM': '/content/drive/MyDrive/Sem 2/CV/5G_Data_rev/16QAM/',
 #   '32QAM': '/content/drive/MyDrive/Sem 2/CV/5G_Data/32QAM/',
    '64QAM': '/content/drive/MyDrive/Sem 2/CV/5G_Data_rev/64QAM/',}

# %%
# get image dimensions
def get_dims(file):
    img = cv2.imread(file)
    h,w = img.shape[:2]
    return h,w

# %%
for n,d in directories.items():
  filepath = d
  filelist = [filepath + f for f in os.listdir(filepath)]
  dims = bag.from_sequence(filelist).map(get_dims)
  with diagnostics.ProgressBar():
    dims = dims.compute()
    dim_df = pd.DataFrame(dims, columns=['height', 'width'])
    sizes = dim_df.groupby(['height', 'width']).size().reset_index().rename(columns={0:'count'})
    sizes.plot.scatter(x='width', y='height');
    plt.title('Image Sizes (pixels) | {}'.format(n))
# Out:
# [########################################] | 100% Completed | 9.95 s
# [########################################] | 100% Completed | 9.04 s
# [########################################] | 100% Completed | 33.77 s

# %% [markdown]
# # **Scolograms**

# %%
dir = directories['64QAM']
label = '64QAM'

def plot_samples(dir, label):
  from tensorflow.keras.preprocessing import image

  fig = plt.figure(figsize = (8,6))
  filelist = [filepath + f for f in os.listdir(dir)]
  files = np.random.choice(filelist, 6, replace = False)
  plt.title(label)
  plt.axis('off')

  for i in range(6):
      ax = fig.add_subplot(2, 3, i+1)
      fn = image.load_img(files[i], target_size = (100,100))
      plt.imshow(fn)
      plt.axis('off')
  plt.show()

# %%
for n,dir in directories.items():
  plot_samples(d,n)

# %%
import PIL.Image

def cs_images(path,img_shape, classes):
    imag = []
    label = []
    for i in classes:
        l1 = os.listdir(path+'/'+i)
        for j in l1:
            img = PIL.Image.open(path+'/'+i+'/'+j)
            img = img.resize(size = (img_shape[0], img_shape[0]))
            img = img.convert('RGB')
            #img = img.convert('L')
            #img = img.reshape(50,50,1)
            #img = img.flatten()
            img = cv2.imread(path+'/'+i+'/'+j)
            img = cv2.resize(img,(img_shape[0],img_shape[1]),3)
            #img = np.array(img).reshape(img_shape)
            #img = img.reshape(img_shape)
            imag.append(img)
            label.append(classes.index(i))
            del(img)
    # %matplotlib inline 
    # plt.figure(figsize=(10, 10))
    # for i in range(20):
    #     plt.subplot(5,4,i+1)
    #     plt.imshow(imag[i])
    #     plt.axis('off')
    # plt.show()
    return np.array(imag),label

# %%
IMG_SIZE = 224

# %%
x,y = cs_images(data_path,(IMG_SIZE, IMG_SIZE, 1),classes)

# %%
y = pd.Series(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 1,shuffle = True)

# %%
x_train.shape
# Out:
# (960, 224, 224, 3)

# %%
y_train[:10]
# Out:
# 1184    2
# 771     1
# 329     0
# 587     1
# 746     1
# 997     2
# 982     2
# 671     1
# 897     2
# 773     1
# dtype: int64

# %%
y_train.shape
# Out:
# (960,)

# %%
x_test.shape
# Out:
# (240, 224, 224, 3)

# %%
y_test.shape
# Out:
# (240,)

# %%
IMG_SIZE = 224

# %% [markdown]
# # **Mobilenet Model**

# %%
IMG_SIZE = 224
BATCH_SIZE = 32

# %%
data_augmentation = tf.keras.Sequential([
                            layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
                            layers.experimental.preprocessing.RandomRotation((-0.2, 0.3))
])

# %%
resize_and_rescale = tf.keras.Sequential([
            layers.experimental.preprocessing.Resizing(IMG_SIZE, IMG_SIZE, input_shape=[IMG_SIZE,IMG_SIZE,3]),
            layers.experimental.preprocessing.Rescaling(1./255)
])
# resize_and_rescale = keras.Sequential([
#   layers.Resizing(IMG_SIZE, IMG_SIZE),
#   layers.Rescaling(1./255)
# ])

# %%
from tensorflow.keras.constraints import MaxNorm

def mobileNet(inp_shape):
  model = Sequential()
  model.add(resize_and_rescale)
  model.add(data_augmentation)
  model.add(MobileNetV2(include_top = False, weights="imagenet", input_shape=inp_shape))
  model.add(Dropout(0.4))
  model.add(Dense(15, activation='relu', kernel_constraint=MaxNorm(3)))
  model.add(Dropout(0.4))
  model.add(tf.keras.layers.GlobalAveragePooling2D())
  model.add(Dense(3, activation = 'softmax'))
  model.layers[0].trainable = False

  return model

# %%
model_mnet = mobileNet((IMG_SIZE, IMG_SIZE, 3))

# %%
opt = tf.keras.optimizers.Adagrad(
    learning_rate= 0.1,
    initial_accumulator_value=0.1,
    epsilon=1e-07,
    weight_decay=None,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    use_ema=False,
    ema_momentum=0.99,
    ema_overwrite_frequency=None,
    jit_compile=True,
    name="Adagrad",
    #**kwargs
)

# %% [markdown]
# ### AdaGrad lr = 1

# %%
opt = tf.keras.optimizers.experimental.SGD(0.1, momentum=0.1)

model_mnet.compile(optimizer= opt, #tf.optimizers.SGD(lr=0.001), 
                   loss = 'sparse_categorical_crossentropy',
                   metrics = 'accuracy')

# %%
model_mnet.build((IMG_SIZE, IMG_SIZE, 3))

# %%
model_mnet.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 224, 224, 3)       0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  dropout_4 (Dropout)         (None, 7, 7, 1280)        0
#
#  dense_4 (Dense)             (None, 7, 7, 15)          19215
#
#  dropout_5 (Dropout)         (None, 7, 7, 15)          0
#
#  global_average_pooling2d_2   (None, 15)               0
#  (GlobalAveragePooling2D)
#
#  dense_5 (Dense)             (None, 3)                 48
#
# =================================================================
# Total params: 2,277,247
# Trainable params: 2,243,135
# Non-trainable params: 34,112
# _________________________________________________________________

# %%
es = [
    keras.callbacks.EarlyStopping(
        # Stop training when `val_loss` is no longer improving
        monitor='val_loss',
        # "no longer improving" being defined as "no better than 1e-2 less"
        min_delta=1e-3,
        # "no longer improving" being further defined as "for at least 2 epochs"
        patience=25,
        verbose=1)
]

# %%
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

# %%
hist_mnet = model_mnet.fit( x_train,
                           y_train,
                           epochs= 100,
                           validation_data = (x_test,y_test),
                           verbose = 1,
                           #callbacks = [es]
                           )
# Out:
# Epoch 1/100
# 30/30 [==============================] - 232s 7s/step - loss: 1.8524 - accuracy: 0.3208 - val_loss: 1.1000 - val_accuracy: 0.3000
# Epoch 2/100
# 30/30 [==============================] - 215s 7s/step - loss: 1.1078 - accuracy: 0.3385 - val_loss: 1.1066 - val_accuracy: 0.3583
# Epoch 3/100
# 30/30 [==============================] - 215s 7s/step - loss: 1.1058 - accuracy: 0.3208 - val_loss: 1.1108 - val_accuracy: 0.3000
# Epoch 4/100
# 30/30 [==============================] - 215s 7s/step - loss: 1.1038 - accuracy: 0.3365 - val_loss: 1.1168 - val_accuracy: 0.3000
# Epoch 5/100
# 30/30 [==============================] - 213s 7s/step - loss: 1.1062 - accuracy: 0.3177 - val_loss: 1.1079 - val_accuracy: 0.3000
# Epoch 6/100
# 30/30 [==============================] - 210s 7s/step - loss: 1.1038 - accuracy: 0.3344 - val_loss: 1.0976 - val_accuracy: 0.3583
# Epoch 7/100
# 30/30 [==============================] - 214s 7s/step - loss: 1.1041 - accuracy: 0.3438 - val_loss: 1.1056 - val_accuracy: 0.3583
# Epoch 8/100
# 30/30 [==============================] - 206s 7s/step - loss: 1.1022 - accuracy: 0.3469 - val_loss: 1.1107 - val_accuracy: 0.3000
# Epoch 9/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1042 - accuracy: 0.3406 - val_loss: 1.1005 - val_accuracy: 0.3000
# Epoch 10/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1033 - accuracy: 0.3281 - val_loss: 1.1053 - val_accuracy: 0.3417
# Epoch 11/100
# 30/30 [==============================] - 208s 7s/step - loss: 1.1019 - accuracy: 0.3219 - val_loss: 1.0969 - val_accuracy: 0.3583
# Epoch 12/100
# 30/30 [==============================] - 205s 7s/step - loss: 1.1037 - accuracy: 0.3396 - val_loss: 1.1041 - val_accuracy: 0.3000
# Epoch 13/100
# 30/30 [==============================] - 206s 7s/step - loss: 1.1019 - accuracy: 0.3281 - val_loss: 1.0987 - val_accuracy: 0.3583
# Epoch 14/100
# 30/30 [==============================] - 205s 7s/step - loss: 1.1031 - accuracy: 0.3396 - val_loss: 1.0979 - val_accuracy: 0.3583
# Epoch 15/100
# 30/30 [==============================] - 208s 7s/step - loss: 1.1015 - accuracy: 0.3438 - val_loss: 1.0998 - val_accuracy: 0.3417
# Epoch 16/100
# 30/30 [==============================] - 208s 7s/step - loss: 1.1025 - accuracy: 0.3167 - val_loss: 1.1036 - val_accuracy: 0.3000
# Epoch 17/100
# 30/30 [==============================] - 208s 7s/step - loss: 1.1024 - accuracy: 0.3427 - val_loss: 1.0968 - val_accuracy: 0.3583
# Epoch 18/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1032 - accuracy: 0.3125 - val_loss: 1.1008 - val_accuracy: 0.3000
# Epoch 19/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1006 - accuracy: 0.3271 - val_loss: 1.1033 - val_accuracy: 0.3417
# Epoch 20/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1043 - accuracy: 0.3125 - val_loss: 1.1024 - val_accuracy: 0.3000
# Epoch 21/100
# 30/30 [==============================] - 208s 7s/step - loss: 1.1021 - accuracy: 0.3115 - val_loss: 1.1024 - val_accuracy: 0.3000
# Epoch 22/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1007 - accuracy: 0.3417 - val_loss: 1.1034 - val_accuracy: 0.3000
# Epoch 23/100
# 30/30 [==============================] - 208s 7s/step - loss: 1.1024 - accuracy: 0.3198 - val_loss: 1.1016 - val_accuracy: 0.3000
# Epoch 24/100
# 30/30 [==============================] - 206s 7s/step - loss: 1.1020 - accuracy: 0.3375 - val_loss: 1.1009 - val_accuracy: 0.3000
# Epoch 25/100
# 30/30 [==============================] - 208s 7s/step - loss: 1.1009 - accuracy: 0.3323 - val_loss: 1.0975 - val_accuracy: 0.3583
# Epoch 26/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1014 - accuracy: 0.3354 - val_loss: 1.1002 - val_accuracy: 0.3000
# Epoch 27/100
# 30/30 [==============================] - 208s 7s/step - loss: 1.1008 - accuracy: 0.3344 - val_loss: 1.1066 - val_accuracy: 0.3000
# Epoch 28/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1034 - accuracy: 0.3281 - val_loss: 1.0984 - val_accuracy: 0.3583
# Epoch 29/100
# 30/30 [==============================] - 208s 7s/step - loss: 1.0993 - accuracy: 0.3333 - val_loss: 1.1086 - val_accuracy: 0.3000
# Epoch 30/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1008 - accuracy: 0.3333 - val_loss: 1.0977 - val_accuracy: 0.3583
# Epoch 31/100
# 30/30 [==============================] - 208s 7s/step - loss: 1.0995 - accuracy: 0.3302 - val_loss: 1.1056 - val_accuracy: 0.3000
# Epoch 32/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1027 - accuracy: 0.3219 - val_loss: 1.1005 - val_accuracy: 0.3583
# Epoch 33/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1004 - accuracy: 0.3438 - val_loss: 1.0961 - val_accuracy: 0.3583
# Epoch 34/100
# 30/30 [==============================] - 205s 7s/step - loss: 1.1031 - accuracy: 0.2990 - val_loss: 1.1022 - val_accuracy: 0.3000
# Epoch 35/100
# 30/30 [==============================] - 210s 7s/step - loss: 1.1017 - accuracy: 0.3146 - val_loss: 1.1010 - val_accuracy: 0.3000
# Epoch 36/100
# 30/30 [==============================] - 219s 7s/step - loss: 1.1015 - accuracy: 0.3229 - val_loss: 1.1038 - val_accuracy: 0.3000
# Epoch 37/100
# 30/30 [==============================] - 212s 7s/step - loss: 1.1012 - accuracy: 0.3042 - val_loss: 1.0998 - val_accuracy: 0.3000
# Epoch 38/100
# 30/30 [==============================] - 208s 7s/step - loss: 1.1013 - accuracy: 0.3104 - val_loss: 1.0990 - val_accuracy: 0.3417
# Epoch 39/100
# 30/30 [==============================] - 217s 7s/step - loss: 1.1002 - accuracy: 0.3271 - val_loss: 1.1044 - val_accuracy: 0.3000
# Epoch 40/100
# 30/30 [==============================] - 214s 7s/step - loss: 1.1027 - accuracy: 0.3187 - val_loss: 1.0986 - val_accuracy: 0.3583
# Epoch 41/100
# 30/30 [==============================] - 211s 7s/step - loss: 1.1004 - accuracy: 0.3260 - val_loss: 1.0995 - val_accuracy: 0.3417
# Epoch 42/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1009 - accuracy: 0.3135 - val_loss: 1.1000 - val_accuracy: 0.3000
# Epoch 43/100
# 30/30 [==============================] - 210s 7s/step - loss: 1.1004 - accuracy: 0.3323 - val_loss: 1.1010 - val_accuracy: 0.3000
# Epoch 44/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1012 - accuracy: 0.3271 - val_loss: 1.0987 - val_accuracy: 0.3417
# Epoch 45/100
# 30/30 [==============================] - 212s 7s/step - loss: 1.0990 - accuracy: 0.3448 - val_loss: 1.0963 - val_accuracy: 0.3583
# Epoch 46/100
# 30/30 [==============================] - 206s 7s/step - loss: 1.1020 - accuracy: 0.2948 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 47/100
# 30/30 [==============================] - 204s 7s/step - loss: 1.1003 - accuracy: 0.3313 - val_loss: 1.1026 - val_accuracy: 0.3000
# Epoch 48/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1009 - accuracy: 0.3406 - val_loss: 1.1013 - val_accuracy: 0.3000
# Epoch 49/100
# 30/30 [==============================] - 206s 7s/step - loss: 1.1004 - accuracy: 0.3208 - val_loss: 1.0982 - val_accuracy: 0.3583
# Epoch 50/100
# 30/30 [==============================] - 211s 7s/step - loss: 1.1029 - accuracy: 0.3187 - val_loss: 1.1009 - val_accuracy: 0.3417
# Epoch 51/100
# 30/30 [==============================] - 211s 7s/step - loss: 1.0994 - accuracy: 0.3063 - val_loss: 1.0978 - val_accuracy: 0.3583
# Epoch 52/100
# 30/30 [==============================] - 211s 7s/step - loss: 1.0994 - accuracy: 0.3448 - val_loss: 1.1041 - val_accuracy: 0.3000
# Epoch 53/100
# 30/30 [==============================] - 211s 7s/step - loss: 1.1012 - accuracy: 0.3354 - val_loss: 1.1038 - val_accuracy: 0.3000
# Epoch 54/100
# 30/30 [==============================] - 227s 8s/step - loss: 1.1000 - accuracy: 0.3313 - val_loss: 1.0980 - val_accuracy: 0.3417
# Epoch 55/100
# 30/30 [==============================] - 212s 7s/step - loss: 1.1010 - accuracy: 0.3177 - val_loss: 1.0983 - val_accuracy: 0.3583
# Epoch 56/100
# 30/30 [==============================] - 212s 7s/step - loss: 1.1008 - accuracy: 0.3260 - val_loss: 1.1030 - val_accuracy: 0.3000
# Epoch 57/100
# 30/30 [==============================] - 218s 7s/step - loss: 1.1005 - accuracy: 0.3187 - val_loss: 1.0994 - val_accuracy: 0.3000
# Epoch 58/100
# 30/30 [==============================] - 215s 7s/step - loss: 1.1001 - accuracy: 0.3323 - val_loss: 1.1007 - val_accuracy: 0.3000
# Epoch 59/100
# 30/30 [==============================] - 212s 7s/step - loss: 1.0997 - accuracy: 0.3198 - val_loss: 1.0994 - val_accuracy: 0.3625
# Epoch 60/100
# 30/30 [==============================] - 205s 7s/step - loss: 1.1002 - accuracy: 0.3396 - val_loss: 1.1013 - val_accuracy: 0.3000
# Epoch 61/100
# 30/30 [==============================] - 205s 7s/step - loss: 1.1006 - accuracy: 0.3365 - val_loss: 1.1021 - val_accuracy: 0.3000
# Epoch 62/100
# 30/30 [==============================] - 205s 7s/step - loss: 1.1002 - accuracy: 0.3406 - val_loss: 1.1012 - val_accuracy: 0.3417
# Epoch 63/100
# 30/30 [==============================] - 206s 7s/step - loss: 1.1111 - accuracy: 0.3604 - val_loss: 1.0977 - val_accuracy: 0.3417
# Epoch 64/100
# 30/30 [==============================] - 204s 7s/step - loss: 1.1003 - accuracy: 0.3104 - val_loss: 1.1017 - val_accuracy: 0.3417
# Epoch 65/100
# 30/30 [==============================] - 208s 7s/step - loss: 1.1005 - accuracy: 0.3198 - val_loss: 1.1002 - val_accuracy: 0.3000
# Epoch 66/100
# 30/30 [==============================] - 203s 7s/step - loss: 1.0997 - accuracy: 0.3323 - val_loss: 1.0993 - val_accuracy: 0.3417
# Epoch 67/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1012 - accuracy: 0.3177 - val_loss: 1.1011 - val_accuracy: 0.3000
# Epoch 68/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.0990 - accuracy: 0.3427 - val_loss: 1.1044 - val_accuracy: 0.3000
# Epoch 69/100
# 30/30 [==============================] - 210s 7s/step - loss: 1.1012 - accuracy: 0.3125 - val_loss: 1.1021 - val_accuracy: 0.3000
# Epoch 70/100
# 30/30 [==============================] - 208s 7s/step - loss: 1.1005 - accuracy: 0.3417 - val_loss: 1.0980 - val_accuracy: 0.3417
# Epoch 71/100
# 30/30 [==============================] - 210s 7s/step - loss: 1.1004 - accuracy: 0.3302 - val_loss: 1.1003 - val_accuracy: 0.3000
# Epoch 72/100
# 30/30 [==============================] - 206s 7s/step - loss: 1.1006 - accuracy: 0.3354 - val_loss: 1.1015 - val_accuracy: 0.3000
# Epoch 73/100
# 30/30 [==============================] - 205s 7s/step - loss: 1.1015 - accuracy: 0.3260 - val_loss: 1.1004 - val_accuracy: 0.3000
# Epoch 74/100
# 30/30 [==============================] - 206s 7s/step - loss: 1.1009 - accuracy: 0.3250 - val_loss: 1.1022 - val_accuracy: 0.3000
# Epoch 75/100
# 30/30 [==============================] - 205s 7s/step - loss: 1.1014 - accuracy: 0.3229 - val_loss: 1.1014 - val_accuracy: 0.3000
# Epoch 76/100
# 30/30 [==============================] - 206s 7s/step - loss: 1.0994 - accuracy: 0.3354 - val_loss: 1.1043 - val_accuracy: 0.3000
# Epoch 77/100
# 30/30 [==============================] - 209s 7s/step - loss: 1.1008 - accuracy: 0.3240 - val_loss: 1.1005 - val_accuracy: 0.3417
# Epoch 78/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1004 - accuracy: 0.3094 - val_loss: 1.0988 - val_accuracy: 0.3583
# Epoch 79/100
# 30/30 [==============================] - 208s 7s/step - loss: 1.1003 - accuracy: 0.3344 - val_loss: 1.0974 - val_accuracy: 0.3417
# Epoch 80/100
# 30/30 [==============================] - 207s 7s/step - loss: 1.1006 - accuracy: 0.3146 - val_loss: 1.1000 - val_accuracy: 0.3000
# Epoch 81/100
# 30/30 [==============================] - 209s 7s/step - loss: 1.1005 - accuracy: 0.3083 - val_loss: 1.0992 - val_accuracy: 0.3000
# Epoch 82/100
# 30/30 [==============================] - 206s 7s/step - loss: 1.0994 - accuracy: 0.3302 - val_loss: 1.1021 - val_accuracy: 0.3417
# Epoch 83/100
# 30/30 [==============================] - 205s 7s/step - loss: 1.1003 - accuracy: 0.3385 - val_loss: 1.1008 - val_accuracy: 0.3000
# Epoch 84/100
# 30/30 [==============================] - 203s 7s/step - loss: 1.1000 - accuracy: 0.3302 - val_loss: 1.0976 - val_accuracy: 0.3417
# Epoch 85/100
# 30/30 [==============================] - 202s 7s/step - loss: 1.1006 - accuracy: 0.3083 - val_loss: 1.0993 - val_accuracy: 0.3000
# Epoch 86/100
# 30/30 [==============================] - 206s 7s/step - loss: 1.1001 - accuracy: 0.3271 - val_loss: 1.0996 - val_accuracy: 0.3000
# Epoch 87/100
# 30/30 [==============================] - 203s 7s/step - loss: 1.1001 - accuracy: 0.3167 - val_loss: 1.0997 - val_accuracy: 0.3000
# Epoch 88/100
# 30/30 [==============================] - 208s 7s/step - loss: 1.0996 - accuracy: 0.3375 - val_loss: 1.0987 - val_accuracy: 0.3417
# Epoch 89/100
# 30/30 [==============================] - 211s 7s/step - loss: 1.1005 - accuracy: 0.2969 - val_loss: 1.1017 - val_accuracy: 0.3000
# Epoch 90/100
# 30/30 [==============================] - 213s 7s/step - loss: 1.0995 - accuracy: 0.3354 - val_loss: 1.0988 - val_accuracy: 0.3417
# Epoch 91/100
# 30/30 [==============================] - 214s 7s/step - loss: 1.1003 - accuracy: 0.3250 - val_loss: 1.1016 - val_accuracy: 0.3000
# Epoch 92/100
# 30/30 [==============================] - 213s 7s/step - loss: 1.1003 - accuracy: 0.3354 - val_loss: 1.0989 - val_accuracy: 0.3000
# Epoch 93/100
# 30/30 [==============================] - 209s 7s/step - loss: 1.0998 - accuracy: 0.3302 - val_loss: 1.1023 - val_accuracy: 0.3000
# Epoch 94/100
# 30/30 [==============================] - 210s 7s/step - loss: 1.1001 - accuracy: 0.3250 - val_loss: 1.1003 - val_accuracy: 0.3417
# Epoch 95/100
# 30/30 [==============================] - 205s 7s/step - loss: 1.0994 - accuracy: 0.3406 - val_loss: 1.0992 - val_accuracy: 0.3583
# Epoch 96/100
# 30/30 [==============================] - 201s 7s/step - loss: 1.0998 - accuracy: 0.3208 - val_loss: 1.1035 - val_accuracy: 0.3000
# Epoch 97/100
# 30/30 [==============================] - 202s 7s/step - loss: 1.1005 - accuracy: 0.3396 - val_loss: 1.0986 - val_accuracy: 0.3583
# Epoch 98/100
# 30/30 [==============================] - 206s 7s/step - loss: 1.0997 - accuracy: 0.3146 - val_loss: 1.0996 - val_accuracy: 0.3000
# Epoch 99/100
# 30/30 [==============================] - 202s 7s/step - loss: 1.0995 - accuracy: 0.3292 - val_loss: 1.1034 - val_accuracy: 0.3000
# Epoch 100/100
# 30/30 [==============================] - 202s 7s/step - loss: 1.1003 - accuracy: 0.3313 - val_loss: 1.1007 - val_accuracy: 0.3000

# %%
y_pred = np.argmax(model_mnet.predict(x_test),axis=1)
# Out:
# 8/8 [==============================] - 9s 932ms/step

# %%
y_pred[0:5]
# Out:
# array([1, 1, 1, 1, 1])

# %%
list(y_test[0:5])
# Out:
# [1, 1, 2, 0, 2]

# %%
model_mnet.evaluate(x_train,y_train)

# %%
model_mnet.evaluate(x_test,y_test)

# %%
print(classes)
print(y_test[:25], '\n')
print(y_pred[:25], '\n')

# predict = []
# for i in range(3000): #len(y_pred)
#   predict.append(np.argmax(y_pred[i]))

# print(predict[:25], '\n')

cm = confusion_matrix(y_test, y_pred)
print(cm, '\n')

zol = zero_one_loss(y_test, y_pred, normalize = False)
print(zol, '\n')

cr = classification_report(y_test, y_pred)
print(cr)

# %%
plt.figure(figsize = (5,5))
ConfusionMatrixDisplay(cm).plot()
plt.show()

# %%
print(hist_mnet.history.keys())

# %%
# summarize history for accuracy
plt.plot(hist_mnet.history['accuracy'])
plt.plot(hist_mnet.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(hist_mnet.history['loss'])
plt.plot(hist_mnet.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # VGG

# %%
from glob import glob 
from tensorflow.keras.layers import Lambda
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
IMAGE_SIZE = [224, 224] #Default image size for VGG16

# ImageDataGenerator can help perform augumentation on existing images. This way, we get more diverse train set.

train_datagen = ImageDataGenerator(rescale = 1./255, shear_range = 0.2, zoom_range = 0.2, horizontal_flip = True)

validation_datagen = ImageDataGenerator(rescale = 1./255)

test_datagen = ImageDataGenerator(rescale = 1./255)
#Through flow_from_directory - we create an array of images that can be used for training.

# %%
#Create a VGG16 model, and removing the last layer that is classifying 1000 images. This will be replaced with images classes we have. 
#vgg = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False) #Training with Imagenet weights
# Use this line for VGG19 network. Create a VGG19 model, and removing the last layer that is classifying 1000 images. This will be replaced with images classes we have. 


vgg = VGG19(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# This sets the base that the layers are not trainable. If we'd want to train the layers with custom data, these two lines can be ommitted. 
for layer in vgg.layers:
  layer.trainable = False

x = Flatten()(vgg.output) #Output obtained on vgg16 is now flattened. 
x = Dropout(0.3)(x)
x = Dense(30, activation='relu')(x)
prediction = Dense(len(classes), activation='softmax')(x) # 
#Creating model object 
model = Model(inputs=vgg.input, outputs=prediction)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 4s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dropout (Dropout)           (None, 25088)             0
#
#  dense (Dense)               (None, 30)                752670
#
#  dense_1 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 20,777,147
# Trainable params: 752,763
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
#opt = keras.optimizers.Adam(learning_rate=0.01)
opt = tf.keras.optimizers.experimental.SGD(0.1, momentum=0.1)
#Compile the model 
model.compile(loss='sparse_categorical_crossentropy', 
              optimizer= opt, 
              metrics=['accuracy'])

# %%
history = model.fit(x_train,
                    y_train,
                    epochs= 200,
                    validation_data = (x_test,y_test),
                    verbose = 1,
                    #callbacks = [es],
                    batch_size=32)
# Out:
# Epoch 1/200
# 30/30 [==============================] - 970s 32s/step - loss: 5074.4995 - accuracy: 0.3396 - val_loss: 1.1004 - val_accuracy: 0.3417
# Epoch 2/200
# 30/30 [==============================] - 957s 32s/step - loss: 1.0994 - accuracy: 0.3208 - val_loss: 1.0999 - val_accuracy: 0.3417
# Epoch 3/200
# 30/30 [==============================] - 953s 32s/step - loss: 1.0981 - accuracy: 0.3177 - val_loss: 1.0988 - val_accuracy: 0.3417
# Epoch 4/200
# 30/30 [==============================] - 952s 32s/step - loss: 1.0983 - accuracy: 0.3219 - val_loss: 1.1001 - val_accuracy: 0.3000
# Epoch 5/200
# 30/30 [==============================] - 936s 31s/step - loss: 1.0985 - accuracy: 0.3219 - val_loss: 1.1002 - val_accuracy: 0.3000
# Epoch 6/200
# 30/30 [==============================] - 930s 31s/step - loss: 1.0970 - accuracy: 0.3375 - val_loss: 1.1002 - val_accuracy: 0.3000
# Epoch 7/200
# 30/30 [==============================] - 929s 31s/step - loss: 1.0983 - accuracy: 0.3333 - val_loss: 1.0997 - val_accuracy: 0.3000
# Epoch 8/200
# 30/30 [==============================] - 927s 31s/step - loss: 1.0961 - accuracy: 0.3302 - val_loss: 1.1002 - val_accuracy: 0.3000
# Epoch 9/200
# 30/30 [==============================] - 927s 31s/step - loss: 1.0936 - accuracy: 0.3240 - val_loss: 1.1013 - val_accuracy: 0.3000
# Epoch 10/200
# 30/30 [==============================] - 926s 31s/step - loss: 1.0948 - accuracy: 0.3240 - val_loss: 1.1006 - val_accuracy: 0.3000
# Epoch 11/200
# 30/30 [==============================] - 928s 31s/step - loss: 1.0969 - accuracy: 0.3313 - val_loss: 1.1014 - val_accuracy: 0.3000
# Epoch 12/200
# 30/30 [==============================] - 931s 31s/step - loss: 1.0947 - accuracy: 0.3313 - val_loss: 1.1018 - val_accuracy: 0.3000
# Epoch 13/200
# 30/30 [==============================] - 927s 31s/step - loss: 1.0947 - accuracy: 0.3458 - val_loss: 1.1017 - val_accuracy: 0.3000
# Epoch 14/200
# 30/30 [==============================] - 927s 31s/step - loss: 1.0939 - accuracy: 0.3448 - val_loss: 1.1017 - val_accuracy: 0.3000
# Epoch 15/200
# 30/30 [==============================] - 926s 31s/step - loss: 1.0279 - accuracy: 0.3969 - val_loss: 0.7459 - val_accuracy: 0.5958
# Epoch 16/200
# 30/30 [==============================] - 936s 31s/step - loss: 0.7384 - accuracy: 0.6062 - val_loss: 0.5942 - val_accuracy: 0.6500
# Epoch 17/200
# 30/30 [==============================] - 932s 31s/step - loss: 0.6417 - accuracy: 0.6302 - val_loss: 0.5553 - val_accuracy: 0.6500
# Epoch 18/200
# 30/30 [==============================] - 926s 31s/step - loss: 0.5659 - accuracy: 0.6573 - val_loss: 0.5122 - val_accuracy: 0.6583
# Epoch 19/200
# 30/30 [==============================] - 926s 31s/step - loss: 0.5306 - accuracy: 0.6677 - val_loss: 0.4960 - val_accuracy: 0.6583
# Epoch 20/200
# 30/30 [==============================] - 924s 31s/step - loss: 0.5234 - accuracy: 0.6573 - val_loss: 0.4864 - val_accuracy: 0.6583
# Epoch 21/200
# 30/30 [==============================] - 925s 31s/step - loss: 0.5062 - accuracy: 0.6687 - val_loss: 0.4789 - val_accuracy: 0.6583
# Epoch 22/200
# 30/30 [==============================] - 925s 31s/step - loss: 0.5159 - accuracy: 0.6687 - val_loss: 0.4758 - val_accuracy: 0.6583
# Epoch 23/200
# 30/30 [==============================] - 924s 31s/step - loss: 0.4959 - accuracy: 0.6583 - val_loss: 0.4722 - val_accuracy: 0.6583
# Epoch 24/200
# 30/30 [==============================] - 928s 31s/step - loss: 0.4992 - accuracy: 0.6667 - val_loss: 0.4684 - val_accuracy: 0.6583
# Epoch 25/200
# 30/30 [==============================] - 925s 31s/step - loss: 0.4970 - accuracy: 0.6562 - val_loss: 0.4661 - val_accuracy: 0.6583
# Epoch 26/200
# 23/30 [======================>.......] - ETA: 2:48 - loss: 0.4932 - accuracy: 0.6739

# %%
# loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
 
 # accuracies
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model.save('/content/drive/MyDrive/Sem 2/CV/Saved_models/sensors_humidity_vgg19.h5')

# %%
y_pred = np.argmax(model.predict(x_test),axis=1)

# %%
y_pred[0:5]

# %%
list(y_test[0:5])

# %%
model.evaluate(x_test,y_test)

# %%
print(classes)
# print(y_test[:25], '\n')
# print(y_pred[:25], '\n')

# predict = []
# for i in range(3000): #len(y_pred)
#   predict.append(np.argmax(y_pred[i]))

# print(predict[:25], '\n')

cm = confusion_matrix(y_test, y_pred)
print(cm, '\n')

zol = zero_one_loss(y_test, y_pred, normalize = False)
print(zol, '\n')

cr = classification_report(y_test, y_pred)
print(cr)

# %%
plt.figure(figsize = (5,5))
ConfusionMatrixDisplay(cm).plot()
plt.show()
